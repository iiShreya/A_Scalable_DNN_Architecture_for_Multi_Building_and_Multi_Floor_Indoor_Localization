# %%
# !git clone https://github.com/kyeongsoo/indoor_localization.git
# Out:
# Cloning into 'indoor_localization'...
# remote: Enumerating objects: 548, done.
# remote: Total 548 (delta 0), reused 0 (delta 0), pack-reused 548
# Receiving objects: 100% (548/548), 7.37 MiB | 13.90 MiB/s, done.
# Resolving deltas: 100% (396/396), done.

# %%
# !python indoor_localization/python/bf_classification.py
# Out:
# Part 1: buidling SAE encoder model ...
# 2022-04-20 11:00:39.975759: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.5491
# Epoch 2/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4813
# Epoch 3/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4722
# Epoch 4/20
# 1793/1793 [==============================] - 8s 5ms/step - loss: 0.4641
# Epoch 5/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4595
# Epoch 6/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4568
# Epoch 7/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4554
# Epoch 8/20
# 1793/1793 [==============================] - 8s 5ms/step - loss: 0.4525
# Epoch 9/20
# 1793/1793 [==============================] - 9s 5ms/step - loss: 0.4519
# ...

# %%
# !python indoor_localization/python/bf_classification_ga.py
# Out:
# Part 1: buidling SAE encoder model ...
# 2022-04-20 11:08:54.696764: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.5289
# Epoch 2/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4765
# Epoch 3/20
# 1793/1793 [==============================] - 10s 6ms/step - loss: 0.4629
# Epoch 4/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4563
# Epoch 5/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4519
# Epoch 6/20
# 1793/1793 [==============================] - 7s 4ms/step - loss: 0.4496
# Epoch 7/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4473
# Epoch 8/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4433
# Epoch 9/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4386
# ...

# %%
# !python indoor_localization/python/bf_multi-label_classification.py
# Out:
# Part 1: buidling SAE encoder model ...
# 2022-04-20 11:13:51.585546: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#
# Part 2: buidling a complete model ...
# Model trained in 9.974206e+01 s.

# %%
# !python indoor_localization/python/data_analysis.py
# Out:
# Intersection of 0-0 and 0-1: {'WAP036', 'WAP057', 'WAP155', 'WAP054', 'WAP053', 'WAP033', 'WAP156', 'WAP161', 'WAP035', 'WAP025', 'WAP162'}
# Intersection of 0-0 and 0-2: {'WAP036', 'WAP155', 'WAP033', 'WAP156', 'WAP162', 'WAP161', 'WAP035', 'WAP025', 'WAP013', 'WAP052'}
# Intersection of 0-0 and 0-3: {'WAP013', 'WAP052'}
# Intersection of 0-0 and 0-4: set()
# Intersection of 0-0 and 1-0: set()
# Intersection of 0-0 and 1-1: set()
# Intersection of 0-0 and 1-2: {'WAP172', 'WAP173'}
# Intersection of 0-0 and 1-3: {'WAP001'}
# Intersection of 0-0 and 1-4: set()
# Intersection of 0-0 and 2-0: {'WAP001'}
# Intersection of 0-0 and 2-1: {'WAP001'}
# Intersection of 0-0 and 2-2: {'WAP001'}
# Intersection of 0-0 and 2-3: set()
# Intersection of 0-0 and 2-4: set()
# Intersection of 0-1 and 0-2: {'WAP034', 'WAP040', 'WAP035', 'WAP025', 'WAP029', 'WAP042', 'WAP026', 'WAP036', 'WAP039', 'WAP009', 'WAP161', 'WAP162', 'WAP155', 'WAP224', 'WAP156', 'WAP143', 'WAP452', 'WAP027', 'WAP030', 'WAP033'}
# ...

# %%
# !python indoor_localization/python/floor_localization.py
# Out:
# Part 1: buidling SAE encoder model ...
# 2022-04-20 10:48:04.768612: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 379/379 [==============================] - 1s 2ms/step - loss: 0.5396
# Epoch 2/30
# 379/379 [==============================] - 1s 2ms/step - loss: 0.5200
# Epoch 3/30
# 379/379 [==============================] - 1s 2ms/step - loss: 0.5124
# Epoch 4/30
# 379/379 [==============================] - 1s 2ms/step - loss: 0.5087
# Epoch 5/30
# 379/379 [==============================] - 1s 2ms/step - loss: 0.5059
# Epoch 6/30
# 379/379 [==============================] - 1s 2ms/step - loss: 0.5064
# Epoch 7/30
# 379/379 [==============================] - 1s 2ms/step - loss: 0.5056
# ...

# %%
# !python indoor_localization/python/data_analysis2.py
# Out:
# Number of spaces in (0-0): 54
# Intersection of (0-0) and (0-0)
# [102 106 107 110 111 112 113 114 115 116 117 118 119 120 121 122 123 125
#  126 127 128 129 130 131 132 133 134 201 202 208 209 211 212 213 214 215
#  216 218 219 220 222 224 225 226 227 229 230 231 232 233 234 235 236 237]
# Number of spaces in (0-1): 66
# Intersection of (0-0) and (0-1)
# [102 106 107 110 111 112 113 114 115 116 117 118 119 120 121 122 123 125
#  126 127 128 129 130 201 202 208 209 211 212 213 214 215 216 218 219 220
#  222 224 225 226 227 229 230 233 234 235]
# Number of spaces in (0-2): 68
# Intersection of (0-0) and (0-2)
# [102 106 107 110 111 112 113 114 115 117 118 119 120 121 122 123 125 126
#  127 128 129 130 132 133 134 201 202 208 209 211 212 213 214 216 218 219
#  220 222 224 225 226 227 229 230 231 234 235]
# Number of spaces in (0-3): 68
# Intersection of (0-0) and (0-3)
# [102 106 107 110 111 112 113 114 115 116 117 118 119 120 121 122 123 125
# ...

# %%
# !python indoor_localization/python/indoor_localization_deep_learning.py
# Out:
# Part 1: buidling SAE encoder model ...
# 2022-04-20 09:48:14.470406: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/20
# 1794/1794 [==============================] - 8s 4ms/step - loss: 0.5366
# Epoch 2/20
# 1794/1794 [==============================] - 8s 4ms/step - loss: 0.4882
# Epoch 3/20
# 1794/1794 [==============================] - 8s 4ms/step - loss: 0.4797
# Epoch 4/20
# 1794/1794 [==============================] - 7s 4ms/step - loss: 0.4743
# Epoch 5/20
# 1794/1794 [==============================] - 8s 5ms/step - loss: 0.4715
# Epoch 6/20
# 1794/1794 [==============================] - 7s 4ms/step - loss: 0.4690
# Epoch 7/20
# 1794/1794 [==============================] - 8s 4ms/step - loss: 0.4676
# Epoch 8/20
# 1794/1794 [==============================] - 9s 5ms/step - loss: 0.4663
# Epoch 9/20
# 1794/1794 [==============================] - 8s 4ms/step - loss: 0.4652
# ...

# %%
# !python indoor_localization/python/indoor_localization_multi-label_classification.py
# Out:
# Part 1: buidling an SAE encoder ...
# 2022-04-20 09:58:00.636281: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.5570
# Epoch 2/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4999
# Epoch 3/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4881
# Epoch 4/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4840
# Epoch 5/20
# 1793/1793 [==============================] - 8s 5ms/step - loss: 0.4811
# Epoch 6/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4792
# Epoch 7/20
# 1793/1793 [==============================] - 8s 5ms/step - loss: 0.4779
# Epoch 8/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4767
# Epoch 9/20
# 1793/1793 [==============================] - 8s 5ms/step - loss: 0.4758
# Epoch 10/20
# ...

# %%
# !python indoor_localization/python/simo_dnn.py
# Out:
# Part 1: buidling an SAE encoder ...
# 2022-04-20 10:55:00.603541: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/20
# 1401/1401 [==============================] - 7s 4ms/step - loss: 0.5624
# Epoch 2/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.5090
# Epoch 3/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.4945
# Epoch 4/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.4820
# Epoch 5/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.4771
# Epoch 6/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.4737
# Epoch 7/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.4711
# Epoch 8/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.4688
# Epoch 9/20
# 1401/1401 [==============================] - 6s 4ms/step - loss: 0.4679
# Epoch 10/20
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 462 kB 5.1 MB/s
# ...

# %%
# !python indoor_localization/python/scalable_indoor_localization_v3.py
# Out:
# Part 1: buidling an SAE encoder ...
# 2022-04-20 11:35:00.459806: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.5497
# Epoch 2/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4897
# Epoch 3/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4691
# Epoch 4/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4604
# Epoch 5/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4541
# Epoch 6/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4469
# Epoch 7/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4444
# Epoch 8/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4415
# Epoch 9/20
# 1793/1793 [==============================] - 8s 4ms/step - loss: 0.4407
# Epoch 10/20
# ...
